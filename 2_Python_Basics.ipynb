# %% [markdown]
# # Python Basics
#
# Python is for everybody! Python can help automate challenging tasks and be reproducible. Python will make your data into a usable state skipping the tedious calculation work and repeating it to other set of data. Different people uses Python:
#
# **Business and Finance**: Accountants and analysts use it to organize finances, automate spreadsheet generation, and parse data.
#
# **Automation**: Everyday professionals use Python to automate repetitive digital tasks, like renaming thousands of files, web scraping, or auto-sending emails.
#
# **Data and Research**: Scientists and researchers rely on it to build quick charts, line graphs, and complex statistical models.

# %% [markdown]
# ### Learning Objectives
# 1. Learn the basics of Python.
# 2. Be able to write a function and return a value.
# 3. Differentiate conditional statements.
# 4. Differentiate lists, dictionaries, and tuples.
# 5. Be able to read a an external file.
# 6. Know how to import important libraries.

# %% [markdown]
# ### Debugging
#
# When you are debugging a program, and especially if you are working on a hard bug, there are four things to try:
#
# **reading** Examine your code, read it back to yourself, and check that it says what you meant to say.
#
# **running** Experiment by making changes and running different versions. Often if you display the right thing at the right place in the program, the problem becomes obvious, but sometimes you have to spend some time to build scaffolding.
#
# **ruminating** Take some time to think! What kind of error is it: syntax, runtime, semantic? What information can you get from the error messages, or from the output of the program? What kind of error could cause the problem you’re seeing? What did you change last, before the problem appeared?
#
# **retreating** At some point, the best thing to do is back off, undoing recent changes, until you get back to a program that works and that you understand. Then you can start rebuilding.

# %% [markdown]
# ## Chap 1. Variables, expressions, and statements

# %% [markdown]
# ## Chap 2. Conditional execution

# %% [markdown]
# ## Chap 3. Functions

# %% [markdown]
# ## Chap 4. Iteration

# %% [markdown]
# ## Chap 5. Strings

# %% [markdown]
# ## Chap 6. Files

# %% [markdown]
# ## Chap 7. Lists

# %% [markdown]
# ## Chap 8. Dictionaries

# %% [markdown]
# ## Chap 9. Tuples

# %% [markdown]
# ## Chap 10. Libraries

# %% [markdown]
# ### References
# 1. A lot of these texts are adopted from Python for Everybody by Charles Severance
